# %% [markdown]
# # addfmt_test — reb_simulation_add_fmt and the solar-system dataset
#
# Adds the built-in solar system plus particles from orbital elements, Pal coordinates, and an orbital period, and dumps all particle states. Verified bit-identical vs the C build.
#
# Crate: `C:\Users\nsh\Developer\github\rustSolveIt_Win11_SUNDIALS_7_8_0\rebound_rust`. This notebook builds the example with cargo (MSVC toolchain, zero unsafe / zero dependencies / zero warnings), runs it, and displays its output. See `rebound_rust.md` for the full provenance.

# %%
import os, subprocess
CRATE = r"C:\Users\nsh\Developer\github\rustSolveIt_Win11_SUNDIALS_7_8_0\rebound_rust"
print(subprocess.run(["cargo", "build", "--release", "--example", "addfmt_test"],
      cwd=CRATE, capture_output=True, text=True).stderr)
# Out:
#     Finished `release` profile [optimized] target(s) in 0.01s

# %%
exe = os.path.join(CRATE, "target", "release", "examples", "addfmt_test.exe")
res = subprocess.run([exe], cwd=os.path.join(CRATE, "porttest"),
                     capture_output=True, text=True)
print(res.stdout)
print(res.stderr)
# Out:
# addfmt done N=12

# %%
print(open(os.path.join(CRATE, "porttest", "addfmt_rust.txt")).read())
# Out:
# 0 3ff0000000000000 bf77e92f474a7c3a 3f7b08faefd0c81c 3f1535939cd3c553 bf3cb0bbf0595160 bf3225552c1373f7 3eeb0c758dbee175
# 1 3e86481bda0dec9c bfd2dee8cfbc47b7 bfd5f9521e18c876 bf6067da5052c22d 3fedba1363148964 bfeee90725dc8c09 bfc502f6a697ceae
# 2 3ec488b15485d885 3fde39b6e63a33ef 3fe18aca0df6131b bf948f0356e3a323 bfec564d1d511360 3fe8bab58c4dc336 3faf96cca86dea32
# 3 3ec9814786657056 3fef36a2abb005c4 bfcc2ccf8099e1be 3f173e61f51f620f 3fcaadc27bfecf31 3fef0dc0df0ed69a bf0156a1a13fca98
# 4 3e95a8363c34797a 3ff6288aa9ae9bb7 bf6e9c1f8015aa31 bfa189875ff60952 3fa2d88c8e40e9ad 3fec3ed933321a10 3f92063a846e2119
# 5 3f4f49600670cda3 40028b2132789ad6 c0124a8768ab2ec7 bfa0d6ee52a1a600 3fd8b21c71de31a8 3fcc0d95ad5dc3d3 bf838a74d36bbb6c
# 6 3f32bc5d9d5f6738 4013eb5b57d0de35 c021552660aa154b bfa85a86bbcc7cbb 3fd0d75b18e06397 3fc492ce42e32de6 bf8b2f0354e01f00
# 7 3f06e445ec947e0b 402f3fab0951d243 4028472199f07f9e bfc4236d2ca9cfbc bfc22b9a94bb9485 3fc5bf41d0888132 3f643c19c849bbc7
# ...
